# %%
# 以静态托管服务器为例， 先运行隔壁的 `访问容器服务器`.ipynb ，两个窗口都不要关闭
# 如果您有其他服务，则忽略 `访问容器服务器`.ipynb 

port_to_be_forward=8084
print(f"访问 http://172.20.137.216:{port_to_be_forward}")

! cp /root/user_docs/relay_to_container_216.id_rsa ~/relay_to_container_216.id_rsa
! chmod 600 ~/relay_to_container_216.id_rsa
! ssh -o StrictHostKeyChecking=no -i ~/relay_to_container_216.id_rsa  -NR 0.0.0.0:{port_to_be_forward}:localhost:{port_to_be_forward} relay_to_container_216@172.20.137.216 -p 23333
# Out:
# 访问 http://172.20.137.216:8084
